# %% [markdown]
# <a href="https://colab.research.google.com/github/Genullz/sales-predictions/blob/main/Project_1_Part_4_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
filename = ('/content/drive/MyDrive/Data Science Bootcamp/01 Week 1: Python/sales_predictions.csv')
df = pd.read_csv(filename)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# Create a minimum of two data visualizations that help others understand trends in the data (explanatory data analysis)

# %%
For_MRP = df.loc[df['Item_MRP']=='MRP','Item_Outlet_Sales'].values
For_Type = df.loc[df['Item_Type']=='TYPE','Item_Outlet_Sales'].values

# %%
sns.boxplot(data=df, x='Item_Outlet_Sales');

# %%
sns.boxplot(data=df, x='Item_Type', y='Item_Outlet_Sales');
plt.xticks(rotation = 90);

# %%
MRP = df['Item_MRP'].values
Type = df['Item_Type'].values
Outlet_Sales = df['Item_Outlet_Sales'].values

# %%
## fig, axes = plt.subplots(nrows = 1, ncols = 1);
plt.figure(figsize=(20,16))
## plt.plot(MRP, Outlet_Sales, c = 'b', label = Type)
plt.scatter(Type, Outlet_Sales, c= 'r', label = MRP);
plt.legend(loc=(1.02,0));
plt.xticks(rotation = 90, fontsize = 16)
plt.yticks(rotation = 90, fontsize = 16);
plt.title('Item_Outlet_Sales', fontsize = 18);
