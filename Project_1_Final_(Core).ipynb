# %% [markdown]
# <a href="https://colab.research.google.com/github/Genullz/sales-predictions/blob/main/Project_1_Final_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn import set_config
set_config(display='diagram')

# %%
path = ('/content/drive/MyDrive/Data Science Bootcamp/01 Week 1: Python/sales_predictions.csv')
ML_df = pd.read_csv(path)
ML_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
ML_df.copy()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %% [markdown]
# Explore the Data

# %%
ML_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# check for duplicates
ML_df.duplicated().sum()
# Out:
# 0

# %%
# check for missing values
ML_df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# for the mean average value of the Item_Weight column.
mean_Item_Weight = ML_df['Item_Weight'].mean()
ML_df['Item_Weight'].fillna(mean_Item_Weight, inplace=True)

# %%
# droping the Outlet_size column
ML_df.drop(columns='Outlet_Size', inplace=True)

# %%
ML_df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
ML_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %% [markdown]
# We see some missing values in Item_Weight and Outlet_Size.

# %%
ML_df['Item_Identifier'].value_counts()

# %% [markdown]
# Train/Test Split

# %%
X = ML_df.drop(columns=['Item_Outlet_Sales'])
y = ML_df['Item_Outlet_Sales']
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#instantiate the selectors to for numeric and categorical data types
num_selector = make_column_selector(dtype_include='number')
cat_selector = make_column_selector(dtype_include='object')
#select the numeric columns of each type
num_columns = num_selector(X_train)
cat_columns = cat_selector(X_train)
#check our lists
print('numeric columns are', num_columns)
print('categorical columns are', cat_columns)
# Out:
# numeric columns are ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year']
# categorical columns are ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Location_Type', 'Outlet_Type']

# %% [markdown]
# The column with missing value has a datatype of a float.

# %%
#instantiate one hot encoder
ohe_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')

# %%
#instantiate mean imputer
mean_imputer = SimpleImputer(strategy='mean')

# %%
# Instantiate the linear regression
lin_reg = LinearRegression()

# %%
# Instantiate 
ohe_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
mean_imputer = SimpleImputer(strategy='mean')
lin_reg = LinearRegression()

# %%
# create a pipeline
lin_reg_pipe = make_pipeline(ohe_encoder, mean_imputer, lin_reg)

# %%
#fit Pipeline
lin_reg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse=False)),
#                 ('simpleimputer', SimpleImputer()),
#                 ('linearregression', LinearRegression())])

# %%
X_train.info()

# %%
# Make predictions using the training and testing data
train_preds = lin_reg_pipe.predict(X_train)
test_preds = lin_reg_pipe.predict(X_test)
train_preds[:10]
# Out:
# array([ 515.3292, 3056.022 , 1577.946 , 1331.6   , 1687.1372,  111.8544,
#        1151.1682, 3401.5722, 3570.0196, 1523.3504])

# %% [markdown]
# Evaluate the performance of your model based on r^2.

# %%
train_r2 = r2_score(y_train, train_preds)
test_r2 = r2_score(y_test, test_preds)

print(f'Model Training R2: {train_r2}')
print(f'Model Testing R2: {test_r2}')
# Out:
# Model Training R2: 1.0
# Model Testing R2: 0.37529775459213344

# %% [markdown]
# Evaluate the performance of your model based on rmse.

# %%
train_RMSE = np.sqrt(np.mean(np.abs(train_preds - y_train)**2))
test_RMSE = np.sqrt(np.mean(np.mean(np.abs(test_preds - y_test)**2)))

print(f'Model Training RMSE: {train_RMSE}')
print(f'Model Testing RMSE: {test_RMSE}')
# Out:
# Model Training RMSE: 1.8278332908904875e-11
# Model Testing RMSE: 1312.8363594607374

# %% [markdown]
# 2. Your second task is to build a regression tree model to predict sales.

# %%
ML_df.info()

# %%
#select the numeric columns of each type
num_columns = num_selector(X_train)
cat_columns = cat_selector(X_train)

# %%
#instantiate an ohe_encoder and a scaler
ohe_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
mean_imputer = SimpleImputer(strategy='mean')

# %%
# Instantiate the Model
dec_tree = DecisionTreeRegressor(random_state = 42)

# %%
dec_tree_pipe = make_pipeline(ohe_encoder, mean_imputer, dec_tree)

# %%
# Fitting the model on the train
dec_tree_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse=False)),
#                 ('simpleimputer', SimpleImputer()),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(random_state=42))])

# %%
# Prediction
train_preds_2 = dec_tree_pipe.predict(X_train)
test_preds_2 = dec_tree_pipe.predict(X_test)
train_preds_2
# Out:
# array([ 515.3292, 3056.022 , 1577.946 , ..., 6145.334 , 1649.8524,
#         965.41  ])

# %%
train_r2 = r2_score(y_train, train_preds_2)
test_r2 = r2_score(y_test, test_preds_2)

print(f'Model Training R2: {train_r2}')
print(f'Model Testing R2: {test_r2}')
# Out:
# Model Training R2: 1.0
# Model Testing R2: 0.07482983282841549

# %%
train_RMSE = np.sqrt(np.mean(np.abs(train_preds_2 - y_train)**2))
test_RMSE = np.sqrt(np.mean(np.mean(np.abs(test_preds_2 - y_test)**2)))

print(f'Model Training RMSE: {train_RMSE}')
print(f'Model Testing RMSE: {test_RMSE}')
# Out:
# Model Training RMSE: 9.851728209784172e-15
# Model Testing RMSE: 1597.661878678554

# %% [markdown]
# 3. You now have tried 2 different models on your data set. You need to determine which model to implement.
#
# Overall, which model do you recommend?
#
# Justify your recommendation.

# %% [markdown]
# I will recommend The linear regession model because the linear regression model can better help our the prediction of the target value of our dataset. The r2 metrics which is best for evaluating your model, Both MSE & RMSE helps to penalize large errors but RMSE uses the same units as the target.

# %% [markdown]
# [Readme](https://https://colab.research.google.com/drive/10ZaOb8dRmbxajt01OZGm11I9q2QbSrFx#scrollTo=98XSQteb9yKp)

# %% [markdown]
# ![Sales Predictions_Page_1.jpg](data:image/jpeg;base64,...)![Sales Predictions_Page_2.jpg](data:image/jpeg;base64,...)![Sales Predictions Readme_Page_2.jpg](data:image/jpeg;base64,...)![Sales Predictions Readme_Page_1.jpg](data:image/jpeg;base64,...)
